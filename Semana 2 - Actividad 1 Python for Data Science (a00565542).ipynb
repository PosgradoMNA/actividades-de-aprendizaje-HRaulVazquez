# %% [markdown]
# **Semana 2 - Actividad 1: Python for Data Science (IBM)**
#
# Reporte de avance del Curso de Python por IBM
#
# Por Héctor R. Vázquez Gléz. (a00565542)

# %% [markdown]
# ![Progreso de Curso 2.png](data:image/png;base64,...)
